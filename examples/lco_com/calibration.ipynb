# %%
import os
import numpy as np
import pandas as pd
import itertools as it
from glob import glob
import matplotlib.pyplot as plt
from sbpy.calib import Sun
from astropy import units as u
from astropy.io import fits

from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from astropy.visualization import ImageNormalize, PercentileInterval, AsinhStretch

from lvmdrp.core.constants import LVM_UNAM_URL
from lvmdrp.utils.examples import fetch_example_data, get_frames_metadata, fix_lamps_metadata, get_masters_metadata

from lvmdrp.core import rss, image, spectrum1d
from lvmdrp.functions import imageMethod, rssMethod, fluxCalMethod

plt.style.use("seaborn-v0_8-talk")

# %%
# define input data directory
data_path = os.path.abspath(os.path.join("..", "data"))

# let's create the output directory
output_path = "./data"
os.makedirs(output_path, exist_ok=True)

# create processed frames path template
out_main_path = os.path.join(output_path, "lvm-{kind}-{camera}-{expnum}.fits")
out_calib_path = os.path.join(output_path, "lvm-{mjd}-{kind}-{camera}-{exptime}.fits")

# overwrite or not
OVERWRITE = True

# %%
# extract metadata
frames_table = get_frames_metadata(path=os.path.join(data_path, "lco_com"), ignore_cache=False).to_pandas()
frames_table = frames_table.loc[~frames_table.mjd.isin([60008,60009,60037,60038])]
# fix arc lamps metadata
fix_lamps_metadata(metadata=frames_table, lamp_names="argon neon ldls hgne xenon krypton".split())
# Out:
# [INFO]: loading cached metadata from '/home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/frames_table.pkl'

# %%
bias_analogs = frames_table.query("imagetyp=='bias'").groupby(["mjd", "camera", "exptime"])

for mjd, camera, exptime in bias_analogs.groups:
    biases = bias_analogs.get_group((mjd, camera, exptime))
    print(biases.to_string())
    
    # let's pre-process the all bias frames
    pbias_paths = []
    for _, bias_frame in biases.iterrows():
        bias_path = bias_frame["path"]
        bias_camera, bias_expnum = bias_frame["camera"], bias_frame["expnum"]

        pbias_path = out_main_path.format(kind="pbias", camera=bias_camera, expnum=bias_expnum)
        pbias_paths.append(pbias_path)
        if not os.path.exists(pbias_path) or OVERWRITE:
            imageMethod.preprocRawFrame_drp(
                in_image=bias_path,
                out_image=pbias_path,
                subtract_overscan=True, unit="electron", compute_error=True,
                os_bound_y="1,4080", os_bound_x="2044,2077"
            )

    imageMethod.createMasterFrame_drp(
        in_images=pbias_paths,
        out_image=out_calib_path.format(mjd=mjd, kind="mbias", camera=bias_camera, exptime=int(exptime))
    )
# Out:
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 500     bias  sp1  60010     b1  00000181      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000181.fits.gz
# 551     bias  sp1  60010     b1  00000176      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000176.fits.gz
# 578     bias  sp1  60010     b1  00000177      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000177.fits.gz
# 674     bias  sp1  60010     b1  00000178      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000178.fits.gz
# 719     bias  sp1  60010     b1  00000180      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000180.fits.gz
# 790     bias  sp1  60010     b1  00000175      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000175.fits.gz
# 847     bias  sp1  60010     b1  00000179      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000179.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.73146456, 'b': 0.78356105, 'c': 0.7180481, 'd': 0.76240355}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000181.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7367415, 'b': 0.78937745, 'c': 0.72518015, 'd': 0.7636367}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000176.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 999.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7308422, 'b': 0.7848677, 'c': 0.72274107, 'd': 0.7667255}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000177.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7364696, 'b': 0.78875077, 'c': 0.7205358, 'd': 0.76351535}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000178.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7343088, 'b': 0.7846065, 'c': 0.7216664, 'd': 0.7640946}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000180.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 999.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.73717386, 'b': 0.78912497, 'c': 0.71567535, 'd': 0.77051276}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000175.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7387538, 'b': 0.7899499, 'c': 0.71381927, 'd': 0.76238436}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000179.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: input frames: ./data/lvm-pbias-b1-00000181.fits,./data/lvm-pbias-b1-00000176.fits,./data/lvm-pbias-b1-00000177.fits,./data/lvm-pbias-b1-00000178.fits,./data/lvm-pbias-b1-00000180.fits,./data/lvm-pbias-b1-00000175.fits,./data/lvm-pbias-b1-00000179.fits
# [INFO]: combining 7 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60010-mbias-b1-0.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 513     bias  sp1  60010     r1  00000176      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000176.fits.gz
# 555     bias  sp1  60010     r1  00000179      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000179.fits.gz
# 573     bias  sp1  60010     r1  00000180      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000180.fits.gz
# 640     bias  sp1  60010     r1  00000177      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000177.fits.gz
# 739     bias  sp1  60010     r1  00000175      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000175.fits.gz
# 746     bias  sp1  60010     r1  00000178      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000178.fits.gz
# 800     bias  sp1  60010     r1  00000181      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000181.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 993.0, 'b': 1008.0, 'c': 1001.0, 'd': 1001.0}
# [INFO]: standard deviation in overscan sections {'a': 2.5146103, 'b': 2.412939, 'c': 2.3334353, 'd': 2.3851044}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000176.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 993.0, 'b': 1008.0, 'c': 1001.0, 'd': 1001.0}
# [INFO]: standard deviation in overscan sections {'a': 2.5073407, 'b': 2.3647025, 'c': 2.330944, 'd': 2.371832}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000179.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 992.0, 'b': 1008.0, 'c': 1000.0, 'd': 1001.0}
# [INFO]: standard deviation in overscan sections {'a': 2.533771, 'b': 2.4269626, 'c': 2.3562624, 'd': 2.4115028}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000180.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 993.0, 'b': 1008.0, 'c': 1001.0, 'd': 1001.0}
# [INFO]: standard deviation in overscan sections {'a': 2.5252697, 'b': 2.4060109, 'c': 2.3422277, 'd': 2.4006271}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000177.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 979.0, 'b': 992.0, 'c': 989.0, 'd': 987.0}
# [INFO]: standard deviation in overscan sections {'a': 2.3086674, 'b': 2.37537, 'c': 2.2627566, 'd': 2.3038702}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000175.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 993.0, 'b': 1008.0, 'c': 1001.0, 'd': 1001.0}
# [INFO]: standard deviation in overscan sections {'a': 2.5175395, 'b': 2.396467, 'c': 2.3486974, 'd': 2.3942935}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000178.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 992.0, 'b': 1008.0, 'c': 1000.0, 'd': 1001.0}
# [INFO]: standard deviation in overscan sections {'a': 2.5418622, 'b': 2.413654, 'c': 2.3522918, 'd': 2.4096682}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000181.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: input frames: ./data/lvm-pbias-r1-00000176.fits,./data/lvm-pbias-r1-00000179.fits,./data/lvm-pbias-r1-00000180.fits,./data/lvm-pbias-r1-00000177.fits,./data/lvm-pbias-r1-00000175.fits,./data/lvm-pbias-r1-00000178.fits,./data/lvm-pbias-r1-00000181.fits
# [INFO]: combining 7 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60010-mbias-r1-0.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 521     bias  sp1  60010     z1  00000179      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000179.fits.gz
# 534     bias  sp1  60010     z1  00000180      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000180.fits.gz
# 570     bias  sp1  60010     z1  00000177      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000177.fits.gz
# 624     bias  sp1  60010     z1  00000181      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000181.fits.gz
# 711     bias  sp1  60010     z1  00000178      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000178.fits.gz
# 715     bias  sp1  60010     z1  00000175      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000175.fits.gz
# 772     bias  sp1  60010     z1  00000176      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000176.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1848114, 'b': 1.2162904, 'c': 1.1337821, 'd': 1.1396236}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z1-00000179.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1870815, 'b': 1.2155397, 'c': 1.1257486, 'd': 1.1441597}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z1-00000180.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.180195, 'b': 1.2085576, 'c': 1.1312656, 'd': 1.1356766}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z1-00000177.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.183474, 'b': 1.2083657, 'c': 1.1310282, 'd': 1.142486}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z1-00000181.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1875502, 'b': 1.2091204, 'c': 1.1324048, 'd': 1.1478157}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z1-00000178.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 995.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1856948, 'b': 1.2193406, 'c': 1.1906952, 'd': 1.2083259}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z1-00000175.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1902398, 'b': 1.2109663, 'c': 1.1354965, 'd': 1.1409088}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z1-00000176.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: input frames: ./data/lvm-pbias-z1-00000179.fits,./data/lvm-pbias-z1-00000180.fits,./data/lvm-pbias-z1-00000177.fits,./data/lvm-pbias-z1-00000181.fits,./data/lvm-pbias-z1-00000178.fits,./data/lvm-pbias-z1-00000175.fits,./data/lvm-pbias-z1-00000176.fits
# [INFO]: combining 7 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60010-mbias-z1-0.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 1851     bias  sp1  60011     b1  00000263      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000263.fits.gz
# 1859     bias  sp1  60011     b1  00000264      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000264.fits.gz
# 1864     bias  sp1  60011     b1  00000261      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000261.fits.gz
# 1908     bias  sp1  60011     b1  00000265      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000265.fits.gz
# 1913     bias  sp1  60011     b1  00000257      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000257.fits.gz
# 1917     bias  sp1  60011     b1  00000262      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000262.fits.gz
# 1926     bias  sp1  60011     b1  00000260      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000260.fits.gz
# 1956     bias  sp1  60011     b1  00000259      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000259.fits.gz
# 1994     bias  sp1  60011     b1  00000266      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000266.fits.gz
# 2008     bias  sp1  60011     b1  00000258      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000258.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7328648, 'b': 0.787082, 'c': 0.71379817, 'd': 0.75573593}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000263.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 999.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7300069, 'b': 0.78641754, 'c': 0.71551466, 'd': 0.7579732}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000264.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7349372, 'b': 0.78533286, 'c': 0.7160688, 'd': 0.7657362}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000261.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.73591965, 'b': 0.7851072, 'c': 0.7175206, 'd': 0.7590121}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000265.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7377937, 'b': 0.7790748, 'c': 0.7166957, 'd': 0.76381785}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000257.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7278934, 'b': 0.78332293, 'c': 0.71221715, 'd': 0.75998074}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000262.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.73277426, 'b': 0.78335863, 'c': 0.7219952, 'd': 0.7595881}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000260.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7320684, 'b': 0.7886191, 'c': 0.7128612, 'd': 0.7611553}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000259.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7342986, 'b': 0.7898212, 'c': 0.71815485, 'd': 0.76376325}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000266.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.72933805, 'b': 0.78533286, 'c': 0.7157474, 'd': 0.75987476}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b1-00000258.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: input frames: ./data/lvm-pbias-b1-00000263.fits,./data/lvm-pbias-b1-00000264.fits,./data/lvm-pbias-b1-00000261.fits,./data/lvm-pbias-b1-00000265.fits,./data/lvm-pbias-b1-00000257.fits,./data/lvm-pbias-b1-00000262.fits,./data/lvm-pbias-b1-00000260.fits,./data/lvm-pbias-b1-00000259.fits,./data/lvm-pbias-b1-00000266.fits,./data/lvm-pbias-b1-00000258.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60011-mbias-b1-0.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 1843     bias  sp1  60011     r1  00000265      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000265.fits.gz
# 1867     bias  sp1  60011     r1  00000259      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000259.fits.gz
# 1880     bias  sp1  60011     r1  00000258      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000258.fits.gz
# 1886     bias  sp1  60011     r1  00000260      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000260.fits.gz
# 1888     bias  sp1  60011     r1  00000262      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000262.fits.gz
# 1928     bias  sp1  60011     r1  00000257      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000257.fits.gz
# 1977     bias  sp1  60011     r1  00000263      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000263.fits.gz
# 2028     bias  sp1  60011     r1  00000261      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000261.fits.gz
# 2040     bias  sp1  60011     r1  00000266      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000266.fits.gz
# 2058     bias  sp1  60011     r1  00000264      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000264.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1017.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.603045, 'b': 1.4341724, 'c': 1.4064851, 'd': 1.4824663}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000265.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1017.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.6135647, 'b': 1.4260684, 'c': 1.4090914, 'd': 1.4797728}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000259.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1016.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.5917315, 'b': 1.4145057, 'c': 1.3861052, 'd': 1.4701036}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000258.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1016.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.6005627, 'b': 1.4116913, 'c': 1.400128, 'd': 1.4887892}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000260.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1017.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.6507747, 'b': 1.4748867, 'c': 1.4468936, 'd': 1.526056}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000262.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1016.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.7251009, 'b': 1.5451024, 'c': 1.4957299, 'd': 1.6016055}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000257.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1017.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.6588644, 'b': 1.4912016, 'c': 1.4562333, 'd': 1.5387263}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000263.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1017.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.6087826, 'b': 1.4255974, 'c': 1.3991181, 'd': 1.4901551}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000261.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1017.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.5964434, 'b': 1.4279847, 'c': 1.403018, 'd': 1.4835286}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000266.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1001.0, 'b': 1016.0, 'c': 1009.0, 'd': 1010.0}
# [INFO]: standard deviation in overscan sections {'a': 1.6456091, 'b': 1.4657612, 'c': 1.4473151, 'd': 1.524102}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r1-00000264.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: input frames: ./data/lvm-pbias-r1-00000265.fits,./data/lvm-pbias-r1-00000259.fits,./data/lvm-pbias-r1-00000258.fits,./data/lvm-pbias-r1-00000260.fits,./data/lvm-pbias-r1-00000262.fits,./data/lvm-pbias-r1-00000257.fits,./data/lvm-pbias-r1-00000263.fits,./data/lvm-pbias-r1-00000261.fits,./data/lvm-pbias-r1-00000266.fits,./data/lvm-pbias-r1-00000264.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60011-mbias-r1-0.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 1845     bias  sp1  60011     z1  00000258      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000258.fits.gz
# 1877     bias  sp1  60011     z1  00000263      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000263.fits.gz
# 1885     bias  sp1  60011     z1  00000260      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000260.fits.gz
# 1947     bias  sp1  60011     z1  00000261      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000261.fits.gz
# 1950     bias  sp1  60011     z1  00000259      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000259.fits.gz
# 1987     bias  sp1  60011     z1  00000264      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000264.fits.gz
# 1995     bias  sp1  60011     z1  00000257      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000257.fits.gz
# 1996     bias  sp1  60011     z1  00000262      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000262.fits.gz
# ...
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1002.0, 'c': 1002.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 5.4697776, 'b': 6.234362, 'c': 5.708094, 'd': 6.138995}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.45, 'b': 2.46, 'c': 2.46, 'd': 2.5}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b2-00000703.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1002.0, 'c': 1002.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 1.8203349, 'b': 1.9194494, 'c': 1.9112046, 'd': 2.1234615}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.45, 'b': 2.46, 'c': 2.46, 'd': 2.5}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b2-00000700.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1002.0, 'c': 1002.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 5.5954537, 'b': 6.375072, 'c': 5.87366, 'd': 6.3383136}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.45, 'b': 2.46, 'c': 2.46, 'd': 2.5}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b2-00000704.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1002.0, 'c': 1002.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 5.544077, 'b': 6.323861, 'c': 5.807534, 'd': 6.2476664}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.45, 'b': 2.46, 'c': 2.46, 'd': 2.5}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b2-00000702.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1002.0, 'c': 1002.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 5.405653, 'b': 6.158479, 'c': 5.6519995, 'd': 6.0734577}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.45, 'b': 2.46, 'c': 2.46, 'd': 2.5}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-b2-00000701.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: input frames: ./data/lvm-pbias-b2-00000703.fits,./data/lvm-pbias-b2-00000700.fits,./data/lvm-pbias-b2-00000704.fits,./data/lvm-pbias-b2-00000702.fits,./data/lvm-pbias-b2-00000701.fits
# [INFO]: combining 5 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60041-mbias-b2-0.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 912      bias  sp2  60041     r2  00000701      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000701.fits.gz
# 936      bias  sp2  60041     r2  00000700      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000700.fits.gz
# 999      bias  sp2  60041     r2  00000702      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000702.fits.gz
# 1013     bias  sp2  60041     r2  00000704      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000704.fits.gz
# 1018     bias  sp2  60041     r2  00000703      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000703.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 994.0, 'b': 995.0, 'c': 1016.0, 'd': 1003.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2730454, 'b': 1.2194902, 'c': 1.1393079, 'd': 1.12003}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.63, 'b': 2.64, 'c': 2.65, 'd': 2.71}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r2-00000701.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 994.0, 'b': 995.0, 'c': 1016.0, 'd': 1003.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2934784, 'b': 1.2522459, 'c': 1.1416875, 'd': 1.125586}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.63, 'b': 2.64, 'c': 2.65, 'd': 2.71}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r2-00000700.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 994.0, 'b': 995.0, 'c': 1016.0, 'd': 1003.0}
# [INFO]: standard deviation in overscan sections {'a': 1.266971, 'b': 1.2270199, 'c': 1.1337049, 'd': 1.1281426}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.63, 'b': 2.64, 'c': 2.65, 'd': 2.71}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r2-00000702.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 994.0, 'b': 995.0, 'c': 1016.0, 'd': 1003.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2590226, 'b': 1.2115756, 'c': 1.1371787, 'd': 1.1194415}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.63, 'b': 2.64, 'c': 2.65, 'd': 2.71}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r2-00000704.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 994.0, 'b': 995.0, 'c': 1016.0, 'd': 1003.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2683152, 'b': 1.2180177, 'c': 1.1345689, 'd': 1.1146066}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.63, 'b': 2.64, 'c': 2.65, 'd': 2.71}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-r2-00000703.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: input frames: ./data/lvm-pbias-r2-00000701.fits,./data/lvm-pbias-r2-00000700.fits,./data/lvm-pbias-r2-00000702.fits,./data/lvm-pbias-r2-00000704.fits,./data/lvm-pbias-r2-00000703.fits
# [INFO]: combining 5 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60041-mbias-r2-0.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 862     bias  sp2  60041     z2  00000700      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000700.fits.gz
# 879     bias  sp2  60041     z2  00000702      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000702.fits.gz
# 895     bias  sp2  60041     z2  00000701      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000701.fits.gz
# 968     bias  sp2  60041     z2  00000703      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000703.fits.gz
# 977     bias  sp2  60041     z2  00000704      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000704.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1005.0, 'c': 1002.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2259585, 'b': 1.3186864, 'c': 1.366, 'd': 1.2779118}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z2-00000700.fits'
# [INFO]: building pixel mask
# [INFO]: 2 (1.2e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1005.0, 'c': 1003.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2284523, 'b': 1.268045, 'c': 1.2118797, 'd': 1.2513318}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z2-00000702.fits'
# [INFO]: building pixel mask
# [INFO]: 2 (1.2e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1005.0, 'c': 1003.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2170628, 'b': 1.2617286, 'c': 1.2071588, 'd': 1.2515041}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z2-00000701.fits'
# [INFO]: building pixel mask
# [INFO]: 2 (1.2e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1005.0, 'c': 1003.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2333568, 'b': 1.27345, 'c': 1.2137842, 'd': 1.2557415}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z2-00000703.fits'
# [INFO]: building pixel mask
# [INFO]: 2 (1.2e-05 %) pixels masked
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1005.0, 'c': 1003.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2258348, 'b': 1.271526, 'c': 1.2116059, 'd': 1.252511}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pbias-z2-00000704.fits'
# [INFO]: building pixel mask
# [INFO]: 2 (1.2e-05 %) pixels masked
# [INFO]: input frames: ./data/lvm-pbias-z2-00000700.fits,./data/lvm-pbias-z2-00000702.fits,./data/lvm-pbias-z2-00000701.fits,./data/lvm-pbias-z2-00000703.fits,./data/lvm-pbias-z2-00000704.fits
# [INFO]: combining 5 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60041-mbias-z2-0.fits'

# %%
bias_analogs = frames_table.query("imagetyp=='bias'").groupby(["camera", "exptime"])

for camera, exptime in bias_analogs.groups:
    biases = bias_analogs.get_group((camera, exptime))
    print(biases.to_string())
    
    # let's pre-process the all bias frames
    pbias_paths = []
    for _, bias_frame in biases.iterrows():
        bias_path = bias_frame["path"]
        bias_camera, bias_expnum = bias_frame["camera"], bias_frame["expnum"]

        pbias_paths.append(out_main_path.format(kind="pbias", camera=bias_camera, expnum=bias_expnum))

    imageMethod.createMasterFrame_drp(
        in_images=pbias_paths,
        out_image=out_calib_path.format(mjd="super", kind="mbias", camera=bias_camera, exptime=int(exptime))
    )
# Out:
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 16       bias  sp1  60039     b1  00000544      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000544.fits.gz
# 25       bias  sp1  60039     b1  00000545      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000545.fits.gz
# 113      bias  sp1  60039     b1  00000542      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000542.fits.gz
# 162      bias  sp1  60039     b1  00000512      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000512.fits.gz
# 176      bias  sp1  60039     b1  00000539      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000539.fits.gz
# 182      bias  sp1  60039     b1  00000546      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000546.fits.gz
# 191      bias  sp1  60039     b1  00000547      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000547.fits.gz
# 214      bias  sp1  60039     b1  00000540      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000540.fits.gz
# 280      bias  sp1  60039     b1  00000548      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000548.fits.gz
# 284      bias  sp1  60039     b1  00000493      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000493.fits.gz
# 328      bias  sp1  60039     b1  00000494      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000494.fits.gz
# 461      bias  sp1  60039     b1  00000541      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000541.fits.gz
# 483      bias  sp1  60039     b1  00000543      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000543.fits.gz
# 500      bias  sp1  60010     b1  00000181      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000181.fits.gz
# 551      bias  sp1  60010     b1  00000176      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000176.fits.gz
# 578      bias  sp1  60010     b1  00000177      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000177.fits.gz
# 674      bias  sp1  60010     b1  00000178      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000178.fits.gz
# 719      bias  sp1  60010     b1  00000180      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000180.fits.gz
# 790      bias  sp1  60010     b1  00000175      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000175.fits.gz
# 847      bias  sp1  60010     b1  00000179      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000179.fits.gz
# 1851     bias  sp1  60011     b1  00000263      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000263.fits.gz
# 1859     bias  sp1  60011     b1  00000264      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000264.fits.gz
# 1864     bias  sp1  60011     b1  00000261      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000261.fits.gz
# 1908     bias  sp1  60011     b1  00000265      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000265.fits.gz
# 1913     bias  sp1  60011     b1  00000257      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000257.fits.gz
# 1917     bias  sp1  60011     b1  00000262      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000262.fits.gz
# 1926     bias  sp1  60011     b1  00000260      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000260.fits.gz
# 1956     bias  sp1  60011     b1  00000259      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000259.fits.gz
# 1994     bias  sp1  60011     b1  00000266      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000266.fits.gz
# 2008     bias  sp1  60011     b1  00000258      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000258.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-b1-00000544.fits,./data/lvm-pbias-b1-00000545.fits,./data/lvm-pbias-b1-00000542.fits,./data/lvm-pbias-b1-00000512.fits,./data/lvm-pbias-b1-00000539.fits,./data/lvm-pbias-b1-00000546.fits,./data/lvm-pbias-b1-00000547.fits,./data/lvm-pbias-b1-00000540.fits,./data/lvm-pbias-b1-00000548.fits,./data/lvm-pbias-b1-00000493.fits,./data/lvm-pbias-b1-00000494.fits,./data/lvm-pbias-b1-00000541.fits,./data/lvm-pbias-b1-00000543.fits,./data/lvm-pbias-b1-00000181.fits,./data/lvm-pbias-b1-00000176.fits,./data/lvm-pbias-b1-00000177.fits,./data/lvm-pbias-b1-00000178.fits,./data/lvm-pbias-b1-00000180.fits,./data/lvm-pbias-b1-00000175.fits,./data/lvm-pbias-b1-00000179.fits,./data/lvm-pbias-b1-00000263.fits,./data/lvm-pbias-b1-00000264.fits,./data/lvm-pbias-b1-00000261.fits,./data/lvm-pbias-b1-00000265.fits,./data/lvm-pbias-b1-00000257.fits,./data/lvm-pbias-b1-00000262.fits,./data/lvm-pbias-b1-00000260.fits,./data/lvm-pbias-b1-00000259.fits,./data/lvm-pbias-b1-00000266.fits,./data/lvm-pbias-b1-00000258.fits
# [INFO]: combining 30 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-b1-0.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 925      bias  sp2  60041     b2  00000703      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000703.fits.gz
# 933      bias  sp2  60041     b2  00000700      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000700.fits.gz
# 990      bias  sp2  60041     b2  00000704      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000704.fits.gz
# 1004     bias  sp2  60041     b2  00000702      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000702.fits.gz
# 1014     bias  sp2  60041     b2  00000701      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000701.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-b2-00000703.fits,./data/lvm-pbias-b2-00000700.fits,./data/lvm-pbias-b2-00000704.fits,./data/lvm-pbias-b2-00000702.fits,./data/lvm-pbias-b2-00000701.fits
# [INFO]: combining 5 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-b2-0.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 4       bias  sp3  60039     b3  00000539      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000539.fits.gz
# 22      bias  sp3  60039     b3  00000547      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000547.fits.gz
# 30      bias  sp3  60039     b3  00000494      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000494.fits.gz
# 77      bias  sp3  60039     b3  00000493      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000493.fits.gz
# 258     bias  sp3  60039     b3  00000542      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000542.fits.gz
# 272     bias  sp3  60039     b3  00000548      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000548.fits.gz
# 321     bias  sp3  60039     b3  00000540      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000540.fits.gz
# 347     bias  sp3  60039     b3  00000546      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000546.fits.gz
# 367     bias  sp3  60039     b3  00000543      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000543.fits.gz
# 389     bias  sp3  60039     b3  00000541      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000541.fits.gz
# 464     bias  sp3  60039     b3  00000545      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000545.fits.gz
# 475     bias  sp3  60039     b3  00000544      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000544.fits.gz
# 492     bias  sp3  60039     b3  00000512      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000512.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-b3-00000539.fits,./data/lvm-pbias-b3-00000547.fits,./data/lvm-pbias-b3-00000494.fits,./data/lvm-pbias-b3-00000493.fits,./data/lvm-pbias-b3-00000542.fits,./data/lvm-pbias-b3-00000548.fits,./data/lvm-pbias-b3-00000540.fits,./data/lvm-pbias-b3-00000546.fits,./data/lvm-pbias-b3-00000543.fits,./data/lvm-pbias-b3-00000541.fits,./data/lvm-pbias-b3-00000545.fits,./data/lvm-pbias-b3-00000544.fits,./data/lvm-pbias-b3-00000512.fits
# [INFO]: combining 13 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-b3-0.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 8        bias  sp1  60039     r1  00000539      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000539.fits.gz
# 9        bias  sp1  60039     r1  00000541      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000541.fits.gz
# 81       bias  sp1  60039     r1  00000548      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000548.fits.gz
# 104      bias  sp1  60039     r1  00000512      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000512.fits.gz
# 141      bias  sp1  60039     r1  00000547      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000547.fits.gz
# 163      bias  sp1  60039     r1  00000493      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000493.fits.gz
# 168      bias  sp1  60039     r1  00000540      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000540.fits.gz
# 283      bias  sp1  60039     r1  00000544      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000544.fits.gz
# 317      bias  sp1  60039     r1  00000543      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000543.fits.gz
# 351      bias  sp1  60039     r1  00000545      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000545.fits.gz
# 398      bias  sp1  60039     r1  00000542      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000542.fits.gz
# 431      bias  sp1  60039     r1  00000546      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000546.fits.gz
# 453      bias  sp1  60039     r1  00000494      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000494.fits.gz
# 513      bias  sp1  60010     r1  00000176      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000176.fits.gz
# 555      bias  sp1  60010     r1  00000179      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000179.fits.gz
# 573      bias  sp1  60010     r1  00000180      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000180.fits.gz
# 640      bias  sp1  60010     r1  00000177      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000177.fits.gz
# 739      bias  sp1  60010     r1  00000175      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000175.fits.gz
# 746      bias  sp1  60010     r1  00000178      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000178.fits.gz
# 800      bias  sp1  60010     r1  00000181      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000181.fits.gz
# 1843     bias  sp1  60011     r1  00000265      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000265.fits.gz
# 1867     bias  sp1  60011     r1  00000259      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000259.fits.gz
# 1880     bias  sp1  60011     r1  00000258      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000258.fits.gz
# 1886     bias  sp1  60011     r1  00000260      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000260.fits.gz
# 1888     bias  sp1  60011     r1  00000262      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000262.fits.gz
# 1928     bias  sp1  60011     r1  00000257      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000257.fits.gz
# 1977     bias  sp1  60011     r1  00000263      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000263.fits.gz
# 2028     bias  sp1  60011     r1  00000261      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000261.fits.gz
# 2040     bias  sp1  60011     r1  00000266      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000266.fits.gz
# 2058     bias  sp1  60011     r1  00000264      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000264.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-r1-00000539.fits,./data/lvm-pbias-r1-00000541.fits,./data/lvm-pbias-r1-00000548.fits,./data/lvm-pbias-r1-00000512.fits,./data/lvm-pbias-r1-00000547.fits,./data/lvm-pbias-r1-00000493.fits,./data/lvm-pbias-r1-00000540.fits,./data/lvm-pbias-r1-00000544.fits,./data/lvm-pbias-r1-00000543.fits,./data/lvm-pbias-r1-00000545.fits,./data/lvm-pbias-r1-00000542.fits,./data/lvm-pbias-r1-00000546.fits,./data/lvm-pbias-r1-00000494.fits,./data/lvm-pbias-r1-00000176.fits,./data/lvm-pbias-r1-00000179.fits,./data/lvm-pbias-r1-00000180.fits,./data/lvm-pbias-r1-00000177.fits,./data/lvm-pbias-r1-00000175.fits,./data/lvm-pbias-r1-00000178.fits,./data/lvm-pbias-r1-00000181.fits,./data/lvm-pbias-r1-00000265.fits,./data/lvm-pbias-r1-00000259.fits,./data/lvm-pbias-r1-00000258.fits,./data/lvm-pbias-r1-00000260.fits,./data/lvm-pbias-r1-00000262.fits,./data/lvm-pbias-r1-00000257.fits,./data/lvm-pbias-r1-00000263.fits,./data/lvm-pbias-r1-00000261.fits,./data/lvm-pbias-r1-00000266.fits,./data/lvm-pbias-r1-00000264.fits
# [INFO]: combining 30 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-r1-0.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 912      bias  sp2  60041     r2  00000701      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000701.fits.gz
# 936      bias  sp2  60041     r2  00000700      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000700.fits.gz
# 999      bias  sp2  60041     r2  00000702      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000702.fits.gz
# 1013     bias  sp2  60041     r2  00000704      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000704.fits.gz
# 1018     bias  sp2  60041     r2  00000703      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000703.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-r2-00000701.fits,./data/lvm-pbias-r2-00000700.fits,./data/lvm-pbias-r2-00000702.fits,./data/lvm-pbias-r2-00000704.fits,./data/lvm-pbias-r2-00000703.fits
# [INFO]: combining 5 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-r2-0.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 119     bias  sp3  60039     r3  00000512      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000512.fits.gz
# 172     bias  sp3  60039     r3  00000543      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000543.fits.gz
# 211     bias  sp3  60039     r3  00000493      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000493.fits.gz
# 217     bias  sp3  60039     r3  00000542      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000542.fits.gz
# 235     bias  sp3  60039     r3  00000544      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000544.fits.gz
# 319     bias  sp3  60039     r3  00000548      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000548.fits.gz
# 363     bias  sp3  60039     r3  00000540      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000540.fits.gz
# 375     bias  sp3  60039     r3  00000541      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000541.fits.gz
# 400     bias  sp3  60039     r3  00000547      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000547.fits.gz
# 437     bias  sp3  60039     r3  00000494      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000494.fits.gz
# 466     bias  sp3  60039     r3  00000539      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000539.fits.gz
# 469     bias  sp3  60039     r3  00000545      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000545.fits.gz
# 484     bias  sp3  60039     r3  00000546      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000546.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-r3-00000512.fits,./data/lvm-pbias-r3-00000543.fits,./data/lvm-pbias-r3-00000493.fits,./data/lvm-pbias-r3-00000542.fits,./data/lvm-pbias-r3-00000544.fits,./data/lvm-pbias-r3-00000548.fits,./data/lvm-pbias-r3-00000540.fits,./data/lvm-pbias-r3-00000541.fits,./data/lvm-pbias-r3-00000547.fits,./data/lvm-pbias-r3-00000494.fits,./data/lvm-pbias-r3-00000539.fits,./data/lvm-pbias-r3-00000545.fits,./data/lvm-pbias-r3-00000546.fits
# [INFO]: combining 13 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-r3-0.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 15       bias  sp1  60039     z1  00000493      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000493.fits.gz
# 86       bias  sp1  60039     z1  00000512      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000512.fits.gz
# 226      bias  sp1  60039     z1  00000540      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000540.fits.gz
# 243      bias  sp1  60039     z1  00000547      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000547.fits.gz
# 302      bias  sp1  60039     z1  00000543      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000543.fits.gz
# 361      bias  sp1  60039     z1  00000541      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000541.fits.gz
# 373      bias  sp1  60039     z1  00000548      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000548.fits.gz
# 396      bias  sp1  60039     z1  00000545      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000545.fits.gz
# 415      bias  sp1  60039     z1  00000544      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000544.fits.gz
# 423      bias  sp1  60039     z1  00000539      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000539.fits.gz
# 430      bias  sp1  60039     z1  00000546      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000546.fits.gz
# 463      bias  sp1  60039     z1  00000494      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000494.fits.gz
# 465      bias  sp1  60039     z1  00000542      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000542.fits.gz
# 521      bias  sp1  60010     z1  00000179      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000179.fits.gz
# 534      bias  sp1  60010     z1  00000180      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000180.fits.gz
# 570      bias  sp1  60010     z1  00000177      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000177.fits.gz
# 624      bias  sp1  60010     z1  00000181      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000181.fits.gz
# 711      bias  sp1  60010     z1  00000178      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000178.fits.gz
# 715      bias  sp1  60010     z1  00000175      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000175.fits.gz
# 772      bias  sp1  60010     z1  00000176      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000176.fits.gz
# 1845     bias  sp1  60011     z1  00000258      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000258.fits.gz
# 1877     bias  sp1  60011     z1  00000263      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000263.fits.gz
# 1885     bias  sp1  60011     z1  00000260      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000260.fits.gz
# 1947     bias  sp1  60011     z1  00000261      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000261.fits.gz
# 1950     bias  sp1  60011     z1  00000259      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000259.fits.gz
# 1987     bias  sp1  60011     z1  00000264      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000264.fits.gz
# 1995     bias  sp1  60011     z1  00000257      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000257.fits.gz
# 1996     bias  sp1  60011     z1  00000262      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000262.fits.gz
# 2007     bias  sp1  60011     z1  00000266      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000266.fits.gz
# 2038     bias  sp1  60011     z1  00000265      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000265.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-z1-00000493.fits,./data/lvm-pbias-z1-00000512.fits,./data/lvm-pbias-z1-00000540.fits,./data/lvm-pbias-z1-00000547.fits,./data/lvm-pbias-z1-00000543.fits,./data/lvm-pbias-z1-00000541.fits,./data/lvm-pbias-z1-00000548.fits,./data/lvm-pbias-z1-00000545.fits,./data/lvm-pbias-z1-00000544.fits,./data/lvm-pbias-z1-00000539.fits,./data/lvm-pbias-z1-00000546.fits,./data/lvm-pbias-z1-00000494.fits,./data/lvm-pbias-z1-00000542.fits,./data/lvm-pbias-z1-00000179.fits,./data/lvm-pbias-z1-00000180.fits,./data/lvm-pbias-z1-00000177.fits,./data/lvm-pbias-z1-00000181.fits,./data/lvm-pbias-z1-00000178.fits,./data/lvm-pbias-z1-00000175.fits,./data/lvm-pbias-z1-00000176.fits,./data/lvm-pbias-z1-00000258.fits,./data/lvm-pbias-z1-00000263.fits,./data/lvm-pbias-z1-00000260.fits,./data/lvm-pbias-z1-00000261.fits,./data/lvm-pbias-z1-00000259.fits,./data/lvm-pbias-z1-00000264.fits,./data/lvm-pbias-z1-00000257.fits,./data/lvm-pbias-z1-00000262.fits,./data/lvm-pbias-z1-00000266.fits,./data/lvm-pbias-z1-00000265.fits
# [INFO]: combining 30 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-z1-0.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 862     bias  sp2  60041     z2  00000700      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000700.fits.gz
# 879     bias  sp2  60041     z2  00000702      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000702.fits.gz
# 895     bias  sp2  60041     z2  00000701      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000701.fits.gz
# 968     bias  sp2  60041     z2  00000703      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000703.fits.gz
# 977     bias  sp2  60041     z2  00000704      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000704.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-z2-00000700.fits,./data/lvm-pbias-z2-00000702.fits,./data/lvm-pbias-z2-00000701.fits,./data/lvm-pbias-z2-00000703.fits,./data/lvm-pbias-z2-00000704.fits
# [INFO]: combining 5 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-z2-0.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 10      bias  sp3  60039     z3  00000493      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000493.fits.gz
# 24      bias  sp3  60039     z3  00000541      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000541.fits.gz
# 44      bias  sp3  60039     z3  00000539      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000539.fits.gz
# 53      bias  sp3  60039     z3  00000540      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000540.fits.gz
# 143     bias  sp3  60039     z3  00000547      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000547.fits.gz
# 170     bias  sp3  60039     z3  00000546      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000546.fits.gz
# 287     bias  sp3  60039     z3  00000545      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000545.fits.gz
# 305     bias  sp3  60039     z3  00000543      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000543.fits.gz
# 309     bias  sp3  60039     z3  00000548      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000548.fits.gz
# 360     bias  sp3  60039     z3  00000512      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000512.fits.gz
# 397     bias  sp3  60039     z3  00000542      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000542.fits.gz
# 442     bias  sp3  60039     z3  00000544      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000544.fits.gz
# 497     bias  sp3  60039     z3  00000494      0.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000494.fits.gz
# [INFO]: input frames: ./data/lvm-pbias-z3-00000493.fits,./data/lvm-pbias-z3-00000541.fits,./data/lvm-pbias-z3-00000539.fits,./data/lvm-pbias-z3-00000540.fits,./data/lvm-pbias-z3-00000547.fits,./data/lvm-pbias-z3-00000546.fits,./data/lvm-pbias-z3-00000545.fits,./data/lvm-pbias-z3-00000543.fits,./data/lvm-pbias-z3-00000548.fits,./data/lvm-pbias-z3-00000512.fits,./data/lvm-pbias-z3-00000542.fits,./data/lvm-pbias-z3-00000544.fits,./data/lvm-pbias-z3-00000494.fits
# [INFO]: combining 13 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mbias-z3-0.fits'

# %%
dark_analogs = frames_table.query("imagetyp=='dark'").groupby(["mjd", "camera", "exptime"])
masters_bias = get_masters_metadata(path_pattern=out_calib_path, mjd="super", kind="mbias")

for mjd, camera, exptime in dark_analogs.groups:
    darks = dark_analogs.get_group((mjd, camera, exptime))
    print(darks.to_string())
    
    master_bias = masters_bias.query("camera==@camera")
    try:
        mbias = master_bias.iloc[0]
    except IndexError:
        imageMethod.image_logger.error(f"no master bias found for {mjd = }, {camera = }, {exptime = }")

    # let's pre-process the all dark frames
    cdark_paths = []
    for _, dark_frame in darks.iterrows():
        dark_path = dark_frame["path"]
        dark_camera, dark_expnum = dark_frame["camera"], dark_frame["expnum"]

        cdark_path = out_main_path.format(kind="cdark", camera=dark_camera, expnum=dark_expnum)
        cdark_paths.append(cdark_path)
        if not os.path.exists(cdark_path) or OVERWRITE:
            imageMethod.preprocRawFrame_drp(
                in_image=dark_path,
                out_image=out_main_path.format(kind="pdark", camera=dark_camera, expnum=dark_expnum),
                subtract_overscan=True, unit="electron", compute_error=True,
                os_bound_y="1,4080", os_bound_x="2044,2077"
            )
            imageMethod.basicCalibration_drp(
                in_image=out_main_path.format(kind="pdark", camera=dark_camera, expnum=dark_expnum),
                out_image=cdark_path,
                in_bias=mbias.path,
            )

    imageMethod.createMasterFrame_drp(
        in_images=cdark_paths,
        out_image=out_calib_path.format(mjd=mjd, kind="mdark", camera=dark_camera, exptime=int(exptime)),
    )
# Out:
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 522     dark  sp1  60010     b1  00000185    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000185.fits.gz
# 646     dark  sp1  60010     b1  00000186    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000186.fits.gz
# 651     dark  sp1  60010     b1  00000182    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000182.fits.gz
# 723     dark  sp1  60010     b1  00000187    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000187.fits.gz
# 726     dark  sp1  60010     b1  00000183    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000183.fits.gz
# 798     dark  sp1  60010     b1  00000184    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000184.fits.gz
# 799     dark  sp1  60010     b1  00000188    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000188.fits.gz
# 803     dark  sp1  60010     b1  00000191    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000191.fits.gz
# 838     dark  sp1  60010     b1  00000189    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000189.fits.gz
# 841     dark  sp1  60010     b1  00000190    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000190.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7387078, 'b': 0.7900245, 'c': 0.7114313, 'd': 0.76526237}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000185.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 999.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7356859, 'b': 0.78631663, 'c': 0.7194276, 'd': 0.7689987}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000186.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 999.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.73435193, 'b': 0.78425545, 'c': 0.7185132, 'd': 0.76045495}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000182.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7348603, 'b': 0.7914374, 'c': 0.7181815, 'd': 0.76563406}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000187.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.73607457, 'b': 0.78566, 'c': 0.71772027, 'd': 0.76185346}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000183.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7327767, 'b': 0.7896159, 'c': 0.71924746, 'd': 0.7656466}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000184.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7358997, 'b': 0.79173666, 'c': 0.71531796, 'd': 0.76674783}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000188.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 999.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7309282, 'b': 0.7914878, 'c': 0.71452296, 'd': 0.76710755}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000191.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.73466617, 'b': 0.7820847, 'c': 0.7158951, 'd': 0.76340854}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000189.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7346055, 'b': 0.79381025, 'c': 0.7170576, 'd': 0.7589}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000190.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: input frames: ./data/lvm-cdark-b1-00000185.fits,./data/lvm-cdark-b1-00000186.fits,./data/lvm-cdark-b1-00000182.fits,./data/lvm-cdark-b1-00000187.fits,./data/lvm-cdark-b1-00000183.fits,./data/lvm-cdark-b1-00000184.fits,./data/lvm-cdark-b1-00000188.fits,./data/lvm-cdark-b1-00000191.fits,./data/lvm-cdark-b1-00000189.fits,./data/lvm-cdark-b1-00000190.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60010-mdark-b1-300.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 528     dark  sp1  60010     r1  00000183    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000183.fits.gz
# 530     dark  sp1  60010     r1  00000186    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000186.fits.gz
# 565     dark  sp1  60010     r1  00000188    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000188.fits.gz
# 594     dark  sp1  60010     r1  00000185    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000185.fits.gz
# 602     dark  sp1  60010     r1  00000184    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000184.fits.gz
# 717     dark  sp1  60010     r1  00000190    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000190.fits.gz
# 730     dark  sp1  60010     r1  00000187    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000187.fits.gz
# 779     dark  sp1  60010     r1  00000191    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000191.fits.gz
# 792     dark  sp1  60010     r1  00000182    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000182.fits.gz
# 849     dark  sp1  60010     r1  00000189    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000189.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 992.0, 'b': 1008.0, 'c': 1000.0, 'd': 1001.0}
# [INFO]: standard deviation in overscan sections {'a': 3.1524858, 'b': 3.2924125, 'c': 2.896255, 'd': 3.0879169}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000183.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 978.0, 'b': 992.0, 'c': 988.0, 'd': 986.0}
# [INFO]: standard deviation in overscan sections {'a': 2.266641, 'b': 2.2904236, 'c': 2.2096157, 'd': 2.209487}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000186.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 992.0, 'b': 1008.0, 'c': 1000.0, 'd': 1001.0}
# [INFO]: standard deviation in overscan sections {'a': 3.0934162, 'b': 3.223196, 'c': 2.834497, 'd': 3.017036}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000188.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 978.0, 'b': 991.0, 'c': 988.0, 'd': 986.0}
# [INFO]: standard deviation in overscan sections {'a': 2.258624, 'b': 2.2746103, 'c': 2.2073715, 'd': 2.1969867}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000185.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 978.0, 'b': 992.0, 'c': 988.0, 'd': 986.0}
# [INFO]: standard deviation in overscan sections {'a': 2.2538564, 'b': 2.2810814, 'c': 2.2058659, 'd': 2.2034187}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000184.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 978.0, 'b': 992.0, 'c': 988.0, 'd': 986.0}
# [INFO]: standard deviation in overscan sections {'a': 2.270202, 'b': 2.2880516, 'c': 2.21249, 'd': 2.206514}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000190.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 978.0, 'b': 992.0, 'c': 988.0, 'd': 986.0}
# [INFO]: standard deviation in overscan sections {'a': 2.2626123, 'b': 2.272333, 'c': 2.2012758, 'd': 2.212989}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000187.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 991.0, 'b': 1007.0, 'c': 999.0, 'd': 1000.0}
# [INFO]: standard deviation in overscan sections {'a': 6.5515075, 'b': 7.3731027, 'c': 5.687128, 'd': 6.724456}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000191.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 978.0, 'b': 992.0, 'c': 988.0, 'd': 986.0}
# [INFO]: standard deviation in overscan sections {'a': 2.267461, 'b': 2.3027306, 'c': 2.2119083, 'd': 2.2231119}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000182.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 978.0, 'b': 992.0, 'c': 988.0, 'd': 986.0}
# [INFO]: standard deviation in overscan sections {'a': 2.2655783, 'b': 2.2756019, 'c': 2.2174802, 'd': 2.2068985}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.75, 'b': 2.79, 'c': 2.68, 'd': 2.74}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r1-00000189.fits'
# [INFO]: building pixel mask
# [INFO]: 4 (2.4e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = r1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: input frames: ./data/lvm-cdark-r1-00000183.fits,./data/lvm-cdark-r1-00000186.fits,./data/lvm-cdark-r1-00000188.fits,./data/lvm-cdark-r1-00000185.fits,./data/lvm-cdark-r1-00000184.fits,./data/lvm-cdark-r1-00000190.fits,./data/lvm-cdark-r1-00000187.fits,./data/lvm-cdark-r1-00000191.fits,./data/lvm-cdark-r1-00000182.fits,./data/lvm-cdark-r1-00000189.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60010-mdark-r1-300.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 502     dark  sp1  60010     z1  00000185    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000185.fits.gz
# 523     dark  sp1  60010     z1  00000190    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000190.fits.gz
# 558     dark  sp1  60010     z1  00000188    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000188.fits.gz
# 561     dark  sp1  60010     z1  00000187    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000187.fits.gz
# 592     dark  sp1  60010     z1  00000184    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000184.fits.gz
# 653     dark  sp1  60010     z1  00000191    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000191.fits.gz
# 716     dark  sp1  60010     z1  00000183    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000183.fits.gz
# 780     dark  sp1  60010     z1  00000189    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000189.fits.gz
# 805     dark  sp1  60010     z1  00000186    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000186.fits.gz
# 821     dark  sp1  60010     z1  00000182    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000182.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1943473, 'b': 1.2117227, 'c': 1.1543258, 'd': 1.1579256}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000185.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1867429, 'b': 1.2114861, 'c': 1.143786, 'd': 1.1631997}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000190.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.186807, 'b': 1.2185519, 'c': 1.1464014, 'd': 1.15853}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000188.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 995.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1788696, 'b': 1.2086818, 'c': 1.1403962, 'd': 1.1600354}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000187.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 995.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.3994107, 'b': 1.2203276, 'c': 1.144457, 'd': 1.1655571}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000184.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 995.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1859424, 'b': 1.2190305, 'c': 1.1413074, 'd': 1.1556389}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000191.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1929555, 'b': 1.214254, 'c': 1.1436986, 'd': 1.1530111}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000183.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1852009, 'b': 1.2142415, 'c': 1.1462538, 'd': 1.1588757}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000189.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 995.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.184847, 'b': 1.2147846, 'c': 1.1412498, 'd': 1.1582739}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000186.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1011.0, 'c': 995.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1872095, 'b': 1.2169893, 'c': 1.1449214, 'd': 1.1545266}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000182.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60010, exptime = 300.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: input frames: ./data/lvm-cdark-z1-00000185.fits,./data/lvm-cdark-z1-00000190.fits,./data/lvm-cdark-z1-00000188.fits,./data/lvm-cdark-z1-00000187.fits,./data/lvm-cdark-z1-00000184.fits,./data/lvm-cdark-z1-00000191.fits,./data/lvm-cdark-z1-00000183.fits,./data/lvm-cdark-z1-00000189.fits,./data/lvm-cdark-z1-00000186.fits,./data/lvm-cdark-z1-00000182.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60010-mdark-z1-300.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 1847     dark  sp1  60011     b1  00000267    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000267.fits.gz
# 1878     dark  sp1  60011     b1  00000276    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000276.fits.gz
# 1895     dark  sp1  60011     b1  00000274    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000274.fits.gz
# 1903     dark  sp1  60011     b1  00000269    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000269.fits.gz
# 1930     dark  sp1  60011     b1  00000272    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000272.fits.gz
# 1945     dark  sp1  60011     b1  00000273    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000273.fits.gz
# 1960     dark  sp1  60011     b1  00000275    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000275.fits.gz
# 1998     dark  sp1  60011     b1  00000268    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000268.fits.gz
# 2001     dark  sp1  60011     b1  00000270    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000270.fits.gz
# 2031     dark  sp1  60011     b1  00000271    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000271.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.73467517, 'b': 0.78604925, 'c': 0.7144625, 'd': 0.763708}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000267.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60011, exptime = 600.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 999.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7385805, 'b': 0.77969414, 'c': 0.71535707, 'd': 0.7601229}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000276.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60011, exptime = 600.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.7345097, 'b': 0.78783154, 'c': 0.7180595, 'd': 0.7629799}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000274.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60011, exptime = 600.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.736365, 'b': 0.7812312, 'c': 0.7139139, 'd': 0.76615083}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b1-00000269.fits'
# [INFO]: building pixel mask
# [INFO]: 0 (0 %) pixels masked
# [INFO]: target frame parameters: MJD = 60011, exptime = 600.0, camera = b1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1000.0, 'b': 1000.0, 'c': 999.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 0.72898996, 'b': 0.78474253, 'c': 0.71119905, 'd': 0.7627824}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.71, 'b': 2.71, 'c': 2.68, 'd': 2.69}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# ...
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1009.0, 'c': 994.0, 'd': 993.0}
# [INFO]: standard deviation in overscan sections {'a': 1.1859695, 'b': 1.2093775, 'c': 1.1284368, 'd': 1.1381212}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.76, 'b': 2.65, 'c': 2.89, 'd': 2.78}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z1-00000646.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: target frame parameters: MJD = 60040, exptime = 900.0, camera = z1
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z1-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [WARNING]: building master frame with one image file
# [INFO]: input frames: ./data/lvm-cdark-z1-00000646.fits
# [INFO]: combining 1 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60040-mdark-z1-900.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 1750     dark  sp2  60040     z2  00000648    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60040/sdR-s-z2-00000648.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1005.0, 'c': 1003.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2425685, 'b': 1.2489227, 'c': 1.2097733, 'd': 1.2414503}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z2-00000648.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60040, exptime = 900.0, camera = z2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [WARNING]: building master frame with one image file
# [INFO]: input frames: ./data/lvm-cdark-z2-00000648.fits
# [INFO]: combining 1 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60040-mdark-z2-900.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 972      dark  sp2  60041     b2  00000707    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000707.fits.gz
# 1021     dark  sp2  60041     b2  00000705    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000705.fits.gz
# 1037     dark  sp2  60041     b2  00000706    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000706.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1002.0, 'c': 1002.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 3.3309271, 'b': 3.7794688, 'c': 3.4122834, 'd': 3.75791}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.45, 'b': 2.46, 'c': 2.46, 'd': 2.5}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b2-00000707.fits'
# [INFO]: building pixel mask
# [INFO]: 6 (3.6e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = b2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1002.0, 'c': 1002.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 3.436494, 'b': 3.9224157, 'c': 3.5261252, 'd': 3.873116}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.45, 'b': 2.46, 'c': 2.46, 'd': 2.5}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b2-00000705.fits'
# [INFO]: building pixel mask
# [INFO]: 6 (3.6e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = b2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1005.0, 'b': 1002.0, 'c': 1002.0, 'd': 999.0}
# [INFO]: standard deviation in overscan sections {'a': 3.3745399, 'b': 3.830338, 'c': 3.461325, 'd': 3.8122628}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.45, 'b': 2.46, 'c': 2.46, 'd': 2.5}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.0, 'b': 3.0, 'c': 2.8, 'd': 2.8}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-b2-00000706.fits'
# [INFO]: building pixel mask
# [INFO]: 6 (3.6e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = b2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-b2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: input frames: ./data/lvm-cdark-b2-00000707.fits,./data/lvm-cdark-b2-00000705.fits,./data/lvm-cdark-b2-00000706.fits
# [INFO]: combining 3 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60041-mdark-b2-900.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 904      dark  sp2  60041     r2  00000705    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000705.fits.gz
# 909      dark  sp2  60041     r2  00000707    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000707.fits.gz
# 1042     dark  sp2  60041     r2  00000706    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000706.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 994.0, 'b': 995.0, 'c': 1016.0, 'd': 1003.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2689524, 'b': 1.2166444, 'c': 1.1354032, 'd': 1.1271014}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.63, 'b': 2.64, 'c': 2.65, 'd': 2.71}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r2-00000705.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = r2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 994.0, 'b': 995.0, 'c': 1016.0, 'd': 1003.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2653912, 'b': 1.2184755, 'c': 1.1390119, 'd': 1.1127703}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.63, 'b': 2.64, 'c': 2.65, 'd': 2.71}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r2-00000707.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = r2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 994.0, 'b': 995.0, 'c': 1016.0, 'd': 1003.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2691109, 'b': 1.2191132, 'c': 1.1433103, 'd': 1.1255975}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.63, 'b': 2.64, 'c': 2.65, 'd': 2.71}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.2, 'b': 3.3, 'c': 3.0, 'd': 3.1}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-r2-00000706.fits'
# [INFO]: building pixel mask
# [INFO]: 1 (6e-06 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = r2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-r2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: input frames: ./data/lvm-cdark-r2-00000705.fits,./data/lvm-cdark-r2-00000707.fits,./data/lvm-cdark-r2-00000706.fits
# [INFO]: combining 3 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60041-mdark-r2-900.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 928      dark  sp2  60041     z2  00000705    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000705.fits.gz
# 966      dark  sp2  60041     z2  00000706    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000706.fits.gz
# 1016     dark  sp2  60041     z2  00000707    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000707.fits.gz
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1004.0, 'c': 1002.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2374811, 'b': 1.2525613, 'c': 1.2090491, 'd': 1.239033}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z2-00000705.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = z2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1004.0, 'c': 1002.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.2446017, 'b': 1.2646836, 'c': 1.2063571, 'd': 1.2427044}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z2-00000706.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = z2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: using given overscan region Y = ['1', '4080'], X = ['2044', '2077']
# [WARNING]: assuming 'TRIMSEC' YX_i = (['1', '4080'], ['1', '2043']), YX_f = (['1', '4080'], ['2078', '4120'])
# [INFO]: median counts in overscan sections {'a': 1004.0, 'b': 1004.0, 'c': 1002.0, 'd': 995.0}
# [INFO]: standard deviation in overscan sections {'a': 1.238509, 'b': 1.2551317, 'c': 1.2073785, 'd': 1.2511259}
# [INFO]: extracted gain values 'GAIN' = {'a': 2.6, 'b': 2.65, 'c': 2.57, 'd': 2.72}
# [INFO]: extracted rdnoise values 'RDNOISE' = {'a': 3.6, 'b': 3.6, 'c': 3.4, 'd': 3.6}
# [INFO]: converting from ADU to e-
# [INFO]: calculated Poisson errors for amplifier 'd'
# [INFO]: flipping along X-axis
# [INFO]: updating header and writing pre-processed frame to './data/lvm-pdark-z2-00000707.fits'
# [INFO]: building pixel mask
# [INFO]: 3 (1.8e-05 %) pixels masked
# [INFO]: target frame parameters: MJD = 60041, exptime = 900.0, camera = z2
# [INFO]: using bias calibration frame './data/lvm-super-mbias-z2-0.fits'
# [INFO]: propagating pixel mask
# [INFO]: replacing NaNs and infinities (0 and 0 pix) with zeros
# [INFO]: input frames: ./data/lvm-cdark-z2-00000705.fits,./data/lvm-cdark-z2-00000706.fits,./data/lvm-cdark-z2-00000707.fits
# [INFO]: combining 3 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-60041-mdark-z2-900.fits'

# %%
dark_analogs = frames_table.query("imagetyp=='dark'").groupby(["camera", "exptime"])

for camera, exptime in dark_analogs.groups:
    darks = dark_analogs.get_group((camera, exptime))
    print(darks.to_string())
    
    master_bias = masters_bias.query("camera==@camera")
    try:
        mbias = master_bias.iloc[0]
    except IndexError:
        imageMethod.image_logger.error(f"no master bias found for {camera = }, {exptime = }")
    
    # let's pre-process the all dark frames
    cdark_paths = []
    for _, dark_frame in darks.iterrows():
        dark_path = dark_frame["path"]
        dark_camera, dark_expnum = dark_frame["camera"], dark_frame["expnum"]

        cdark_paths.append(out_main_path.format(kind="cdark", camera=dark_camera, expnum=dark_expnum))

    imageMethod.createMasterFrame_drp(
        in_images=cdark_paths,
        out_image=out_calib_path.format(mjd="super", kind="mdark", camera=dark_camera, exptime=int(exptime))
    )
# Out:
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 338     dark  sp1  60039     b1  00000518      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000518.fits.gz
# 494     dark  sp1  60039     b1  00000516      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000516.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-b1-00000518.fits,./data/lvm-cdark-b1-00000516.fits
# [INFO]: combining 2 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-b1-5.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 36      dark  sp1  60039     b1  00000595     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000595.fits.gz
# 37      dark  sp1  60039     b1  00000598     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000598.fits.gz
# 166     dark  sp1  60039     b1  00000596     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000596.fits.gz
# 202     dark  sp1  60039     b1  00000597     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000597.fits.gz
# 203     dark  sp1  60039     b1  00000600     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000600.fits.gz
# 250     dark  sp1  60039     b1  00000602     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000602.fits.gz
# 454     dark  sp1  60039     b1  00000599     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000599.fits.gz
# 471     dark  sp1  60039     b1  00000594     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000594.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-b1-00000595.fits,./data/lvm-cdark-b1-00000598.fits,./data/lvm-cdark-b1-00000596.fits,./data/lvm-cdark-b1-00000597.fits,./data/lvm-cdark-b1-00000600.fits,./data/lvm-cdark-b1-00000602.fits,./data/lvm-cdark-b1-00000599.fits,./data/lvm-cdark-b1-00000594.fits
# [INFO]: combining 8 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-b1-60.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 522     dark  sp1  60010     b1  00000185    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000185.fits.gz
# 646     dark  sp1  60010     b1  00000186    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000186.fits.gz
# 651     dark  sp1  60010     b1  00000182    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000182.fits.gz
# 723     dark  sp1  60010     b1  00000187    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000187.fits.gz
# 726     dark  sp1  60010     b1  00000183    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000183.fits.gz
# 798     dark  sp1  60010     b1  00000184    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000184.fits.gz
# 799     dark  sp1  60010     b1  00000188    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000188.fits.gz
# 803     dark  sp1  60010     b1  00000191    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000191.fits.gz
# 838     dark  sp1  60010     b1  00000189    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000189.fits.gz
# 841     dark  sp1  60010     b1  00000190    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-b1-00000190.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-b1-00000185.fits,./data/lvm-cdark-b1-00000186.fits,./data/lvm-cdark-b1-00000182.fits,./data/lvm-cdark-b1-00000187.fits,./data/lvm-cdark-b1-00000183.fits,./data/lvm-cdark-b1-00000184.fits,./data/lvm-cdark-b1-00000188.fits,./data/lvm-cdark-b1-00000191.fits,./data/lvm-cdark-b1-00000189.fits,./data/lvm-cdark-b1-00000190.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-b1-300.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 12       dark  sp1  60039     b1  00000550    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000550.fits.gz
# 71       dark  sp1  60039     b1  00000552    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000552.fits.gz
# 212      dark  sp1  60039     b1  00000551    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000551.fits.gz
# 240      dark  sp1  60039     b1  00000554    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000554.fits.gz
# 253      dark  sp1  60039     b1  00000553    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000553.fits.gz
# 255      dark  sp1  60039     b1  00000555    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000555.fits.gz
# 456      dark  sp1  60039     b1  00000556    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000556.fits.gz
# 481      dark  sp1  60039     b1  00000558    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000558.fits.gz
# 485      dark  sp1  60039     b1  00000557    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000557.fits.gz
# 491      dark  sp1  60039     b1  00000549    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b1-00000549.fits.gz
# 1847     dark  sp1  60011     b1  00000267    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000267.fits.gz
# 1878     dark  sp1  60011     b1  00000276    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000276.fits.gz
# 1895     dark  sp1  60011     b1  00000274    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000274.fits.gz
# 1903     dark  sp1  60011     b1  00000269    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000269.fits.gz
# 1930     dark  sp1  60011     b1  00000272    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000272.fits.gz
# 1945     dark  sp1  60011     b1  00000273    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000273.fits.gz
# 1960     dark  sp1  60011     b1  00000275    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000275.fits.gz
# 1998     dark  sp1  60011     b1  00000268    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000268.fits.gz
# 2001     dark  sp1  60011     b1  00000270    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000270.fits.gz
# 2031     dark  sp1  60011     b1  00000271    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-b1-00000271.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-b1-00000550.fits,./data/lvm-cdark-b1-00000552.fits,./data/lvm-cdark-b1-00000551.fits,./data/lvm-cdark-b1-00000554.fits,./data/lvm-cdark-b1-00000553.fits,./data/lvm-cdark-b1-00000555.fits,./data/lvm-cdark-b1-00000556.fits,./data/lvm-cdark-b1-00000558.fits,./data/lvm-cdark-b1-00000557.fits,./data/lvm-cdark-b1-00000549.fits,./data/lvm-cdark-b1-00000267.fits,./data/lvm-cdark-b1-00000276.fits,./data/lvm-cdark-b1-00000274.fits,./data/lvm-cdark-b1-00000269.fits,./data/lvm-cdark-b1-00000272.fits,./data/lvm-cdark-b1-00000273.fits,./data/lvm-cdark-b1-00000275.fits,./data/lvm-cdark-b1-00000268.fits,./data/lvm-cdark-b1-00000270.fits,./data/lvm-cdark-b1-00000271.fits
# [INFO]: combining 20 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-b1-600.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 1789     dark  sp1  60040     b1  00000646    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60040/sdR-s-b1-00000646.fits.gz
# [WARNING]: building master frame with one image file
# [INFO]: input frames: ./data/lvm-cdark-b1-00000646.fits
# [INFO]: combining 1 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-b1-900.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 972      dark  sp2  60041     b2  00000707    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000707.fits.gz
# 1021     dark  sp2  60041     b2  00000705    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000705.fits.gz
# 1037     dark  sp2  60041     b2  00000706    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-b2-00000706.fits.gz
# 1729     dark  sp2  60040     b2  00000648    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60040/sdR-s-b2-00000648.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-b2-00000707.fits,./data/lvm-cdark-b2-00000705.fits,./data/lvm-cdark-b2-00000706.fits,./data/lvm-cdark-b2-00000648.fits
# [INFO]: combining 4 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-b2-900.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 29      dark  sp3  60039     b3  00000518      5.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000518.fits.gz
# 388     dark  sp3  60039     b3  00000517      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000517.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-b3-00000518.fits,./data/lvm-cdark-b3-00000517.fits
# [INFO]: combining 2 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-b3-5.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 93      dark  sp3  60039     b3  00000557    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000557.fits.gz
# 194     dark  sp3  60039     b3  00000554    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000554.fits.gz
# 206     dark  sp3  60039     b3  00000556    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000556.fits.gz
# 210     dark  sp3  60039     b3  00000550    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000550.fits.gz
# 256     dark  sp3  60039     b3  00000555    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000555.fits.gz
# 294     dark  sp3  60039     b3  00000549    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000549.fits.gz
# 337     dark  sp3  60039     b3  00000553    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000553.fits.gz
# 390     dark  sp3  60039     b3  00000552    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000552.fits.gz
# 493     dark  sp3  60039     b3  00000551    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000551.fits.gz
# 496     dark  sp3  60039     b3  00000558    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-b3-00000558.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-b3-00000557.fits,./data/lvm-cdark-b3-00000554.fits,./data/lvm-cdark-b3-00000556.fits,./data/lvm-cdark-b3-00000550.fits,./data/lvm-cdark-b3-00000555.fits,./data/lvm-cdark-b3-00000549.fits,./data/lvm-cdark-b3-00000553.fits,./data/lvm-cdark-b3-00000552.fits,./data/lvm-cdark-b3-00000551.fits,./data/lvm-cdark-b3-00000558.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-b3-600.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 136     dark  sp1  60039     r1  00000516      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000516.fits.gz
# 300     dark  sp1  60039     r1  00000518      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000518.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-r1-00000516.fits,./data/lvm-cdark-r1-00000518.fits
# [INFO]: combining 2 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-r1-5.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 169     dark  sp1  60039     r1  00000597     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000597.fits.gz
# 248     dark  sp1  60039     r1  00000599     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000599.fits.gz
# 257     dark  sp1  60039     r1  00000598     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000598.fits.gz
# 322     dark  sp1  60039     r1  00000595     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000595.fits.gz
# 336     dark  sp1  60039     r1  00000602     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000602.fits.gz
# 376     dark  sp1  60039     r1  00000600     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000600.fits.gz
# 378     dark  sp1  60039     r1  00000594     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000594.fits.gz
# 384     dark  sp1  60039     r1  00000596     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000596.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-r1-00000597.fits,./data/lvm-cdark-r1-00000599.fits,./data/lvm-cdark-r1-00000598.fits,./data/lvm-cdark-r1-00000595.fits,./data/lvm-cdark-r1-00000602.fits,./data/lvm-cdark-r1-00000600.fits,./data/lvm-cdark-r1-00000594.fits,./data/lvm-cdark-r1-00000596.fits
# [INFO]: combining 8 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-r1-60.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 528     dark  sp1  60010     r1  00000183    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000183.fits.gz
# 530     dark  sp1  60010     r1  00000186    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000186.fits.gz
# 565     dark  sp1  60010     r1  00000188    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000188.fits.gz
# 594     dark  sp1  60010     r1  00000185    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000185.fits.gz
# 602     dark  sp1  60010     r1  00000184    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000184.fits.gz
# 717     dark  sp1  60010     r1  00000190    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000190.fits.gz
# 730     dark  sp1  60010     r1  00000187    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000187.fits.gz
# 779     dark  sp1  60010     r1  00000191    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000191.fits.gz
# 792     dark  sp1  60010     r1  00000182    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000182.fits.gz
# 849     dark  sp1  60010     r1  00000189    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-r1-00000189.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-r1-00000183.fits,./data/lvm-cdark-r1-00000186.fits,./data/lvm-cdark-r1-00000188.fits,./data/lvm-cdark-r1-00000185.fits,./data/lvm-cdark-r1-00000184.fits,./data/lvm-cdark-r1-00000190.fits,./data/lvm-cdark-r1-00000187.fits,./data/lvm-cdark-r1-00000191.fits,./data/lvm-cdark-r1-00000182.fits,./data/lvm-cdark-r1-00000189.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-r1-300.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 108      dark  sp1  60039     r1  00000550    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000550.fits.gz
# 144      dark  sp1  60039     r1  00000552    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000552.fits.gz
# 160      dark  sp1  60039     r1  00000556    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000556.fits.gz
# 222      dark  sp1  60039     r1  00000551    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000551.fits.gz
# 298      dark  sp1  60039     r1  00000557    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000557.fits.gz
# 357      dark  sp1  60039     r1  00000553    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000553.fits.gz
# 407      dark  sp1  60039     r1  00000554    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000554.fits.gz
# 439      dark  sp1  60039     r1  00000555    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000555.fits.gz
# 480      dark  sp1  60039     r1  00000558    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000558.fits.gz
# 490      dark  sp1  60039     r1  00000549    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r1-00000549.fits.gz
# 1842     dark  sp1  60011     r1  00000275    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000275.fits.gz
# 1865     dark  sp1  60011     r1  00000270    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000270.fits.gz
# 1876     dark  sp1  60011     r1  00000274    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000274.fits.gz
# 1907     dark  sp1  60011     r1  00000272    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000272.fits.gz
# 1912     dark  sp1  60011     r1  00000269    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000269.fits.gz
# 1976     dark  sp1  60011     r1  00000271    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000271.fits.gz
# 1979     dark  sp1  60011     r1  00000267    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000267.fits.gz
# 2019     dark  sp1  60011     r1  00000273    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000273.fits.gz
# 2029     dark  sp1  60011     r1  00000268    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000268.fits.gz
# 2037     dark  sp1  60011     r1  00000276    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-r1-00000276.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-r1-00000550.fits,./data/lvm-cdark-r1-00000552.fits,./data/lvm-cdark-r1-00000556.fits,./data/lvm-cdark-r1-00000551.fits,./data/lvm-cdark-r1-00000557.fits,./data/lvm-cdark-r1-00000553.fits,./data/lvm-cdark-r1-00000554.fits,./data/lvm-cdark-r1-00000555.fits,./data/lvm-cdark-r1-00000558.fits,./data/lvm-cdark-r1-00000549.fits,./data/lvm-cdark-r1-00000275.fits,./data/lvm-cdark-r1-00000270.fits,./data/lvm-cdark-r1-00000274.fits,./data/lvm-cdark-r1-00000272.fits,./data/lvm-cdark-r1-00000269.fits,./data/lvm-cdark-r1-00000271.fits,./data/lvm-cdark-r1-00000267.fits,./data/lvm-cdark-r1-00000273.fits,./data/lvm-cdark-r1-00000268.fits,./data/lvm-cdark-r1-00000276.fits
# [INFO]: combining 20 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-r1-600.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 1839     dark  sp1  60040     r1  00000646    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60040/sdR-s-r1-00000646.fits.gz
# [WARNING]: building master frame with one image file
# [INFO]: input frames: ./data/lvm-cdark-r1-00000646.fits
# [INFO]: combining 1 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-r1-900.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 904      dark  sp2  60041     r2  00000705    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000705.fits.gz
# 909      dark  sp2  60041     r2  00000707    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000707.fits.gz
# 1042     dark  sp2  60041     r2  00000706    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-r2-00000706.fits.gz
# 1754     dark  sp2  60040     r2  00000648    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60040/sdR-s-r2-00000648.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-r2-00000705.fits,./data/lvm-cdark-r2-00000707.fits,./data/lvm-cdark-r2-00000706.fits,./data/lvm-cdark-r2-00000648.fits
# [INFO]: combining 4 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-r2-900.fits'
#    imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 49     dark  sp3  60039     r3  00000517      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000517.fits.gz
# 79     dark  sp3  60039     r3  00000518      5.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000518.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-r3-00000517.fits,./data/lvm-cdark-r3-00000518.fits
# [INFO]: combining 2 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-r3-5.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 50      dark  sp3  60039     r3  00000557    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000557.fits.gz
# 228     dark  sp3  60039     r3  00000550    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000550.fits.gz
# 259     dark  sp3  60039     r3  00000554    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000554.fits.gz
# 290     dark  sp3  60039     r3  00000558    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000558.fits.gz
# 297     dark  sp3  60039     r3  00000549    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000549.fits.gz
# 307     dark  sp3  60039     r3  00000553    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000553.fits.gz
# 327     dark  sp3  60039     r3  00000555    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000555.fits.gz
# 438     dark  sp3  60039     r3  00000551    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000551.fits.gz
# 449     dark  sp3  60039     r3  00000552    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000552.fits.gz
# 467     dark  sp3  60039     r3  00000556    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-r3-00000556.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-r3-00000557.fits,./data/lvm-cdark-r3-00000550.fits,./data/lvm-cdark-r3-00000554.fits,./data/lvm-cdark-r3-00000558.fits,./data/lvm-cdark-r3-00000549.fits,./data/lvm-cdark-r3-00000553.fits,./data/lvm-cdark-r3-00000555.fits,./data/lvm-cdark-r3-00000551.fits,./data/lvm-cdark-r3-00000552.fits,./data/lvm-cdark-r3-00000556.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-r3-600.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 74      dark  sp1  60039     z1  00000516      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000516.fits.gz
# 413     dark  sp1  60039     z1  00000518      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000518.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-z1-00000516.fits,./data/lvm-cdark-z1-00000518.fits
# [INFO]: combining 2 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-z1-5.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 21      dark  sp1  60039     z1  00000598     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000598.fits.gz
# 75      dark  sp1  60039     z1  00000600     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000600.fits.gz
# 118     dark  sp1  60039     z1  00000594     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000594.fits.gz
# 137     dark  sp1  60039     z1  00000602     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000602.fits.gz
# 161     dark  sp1  60039     z1  00000597     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000597.fits.gz
# 289     dark  sp1  60039     z1  00000596     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000596.fits.gz
# 341     dark  sp1  60039     z1  00000595     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000595.fits.gz
# 369     dark  sp1  60039     z1  00000599     60.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000599.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-z1-00000598.fits,./data/lvm-cdark-z1-00000600.fits,./data/lvm-cdark-z1-00000594.fits,./data/lvm-cdark-z1-00000602.fits,./data/lvm-cdark-z1-00000597.fits,./data/lvm-cdark-z1-00000596.fits,./data/lvm-cdark-z1-00000595.fits,./data/lvm-cdark-z1-00000599.fits
# [INFO]: combining 8 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-z1-60.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 502     dark  sp1  60010     z1  00000185    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000185.fits.gz
# 523     dark  sp1  60010     z1  00000190    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000190.fits.gz
# 558     dark  sp1  60010     z1  00000188    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000188.fits.gz
# 561     dark  sp1  60010     z1  00000187    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000187.fits.gz
# 592     dark  sp1  60010     z1  00000184    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000184.fits.gz
# 653     dark  sp1  60010     z1  00000191    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000191.fits.gz
# 716     dark  sp1  60010     z1  00000183    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000183.fits.gz
# 780     dark  sp1  60010     z1  00000189    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000189.fits.gz
# 805     dark  sp1  60010     z1  00000186    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000186.fits.gz
# 821     dark  sp1  60010     z1  00000182    300.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60010/sdR-s-z1-00000182.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-z1-00000185.fits,./data/lvm-cdark-z1-00000190.fits,./data/lvm-cdark-z1-00000188.fits,./data/lvm-cdark-z1-00000187.fits,./data/lvm-cdark-z1-00000184.fits,./data/lvm-cdark-z1-00000191.fits,./data/lvm-cdark-z1-00000183.fits,./data/lvm-cdark-z1-00000189.fits,./data/lvm-cdark-z1-00000186.fits,./data/lvm-cdark-z1-00000182.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-z1-300.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 68       dark  sp1  60039     z1  00000550    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000550.fits.gz
# 89       dark  sp1  60039     z1  00000551    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000551.fits.gz
# 97       dark  sp1  60039     z1  00000554    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000554.fits.gz
# 139      dark  sp1  60039     z1  00000556    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000556.fits.gz
# 174      dark  sp1  60039     z1  00000552    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000552.fits.gz
# 184      dark  sp1  60039     z1  00000557    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000557.fits.gz
# 325      dark  sp1  60039     z1  00000553    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000553.fits.gz
# 411      dark  sp1  60039     z1  00000555    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000555.fits.gz
# 462      dark  sp1  60039     z1  00000549    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000549.fits.gz
# 495      dark  sp1  60039     z1  00000558    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z1-00000558.fits.gz
# 1862     dark  sp1  60011     z1  00000272    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000272.fits.gz
# 1866     dark  sp1  60011     z1  00000274    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000274.fits.gz
# 1902     dark  sp1  60011     z1  00000275    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000275.fits.gz
# 1905     dark  sp1  60011     z1  00000267    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000267.fits.gz
# 1939     dark  sp1  60011     z1  00000273    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000273.fits.gz
# 1961     dark  sp1  60011     z1  00000276    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000276.fits.gz
# 1962     dark  sp1  60011     z1  00000271    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000271.fits.gz
# 2006     dark  sp1  60011     z1  00000268    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000268.fits.gz
# 2009     dark  sp1  60011     z1  00000270    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000270.fits.gz
# 2027     dark  sp1  60011     z1  00000269    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60011/sdR-s-z1-00000269.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-z1-00000550.fits,./data/lvm-cdark-z1-00000551.fits,./data/lvm-cdark-z1-00000554.fits,./data/lvm-cdark-z1-00000556.fits,./data/lvm-cdark-z1-00000552.fits,./data/lvm-cdark-z1-00000557.fits,./data/lvm-cdark-z1-00000553.fits,./data/lvm-cdark-z1-00000555.fits,./data/lvm-cdark-z1-00000549.fits,./data/lvm-cdark-z1-00000558.fits,./data/lvm-cdark-z1-00000272.fits,./data/lvm-cdark-z1-00000274.fits,./data/lvm-cdark-z1-00000275.fits,./data/lvm-cdark-z1-00000267.fits,./data/lvm-cdark-z1-00000273.fits,./data/lvm-cdark-z1-00000276.fits,./data/lvm-cdark-z1-00000271.fits,./data/lvm-cdark-z1-00000268.fits,./data/lvm-cdark-z1-00000270.fits,./data/lvm-cdark-z1-00000269.fits
# [INFO]: combining 20 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-z1-600.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 1793     dark  sp1  60040     z1  00000646    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60040/sdR-s-z1-00000646.fits.gz
# [WARNING]: building master frame with one image file
# [INFO]: input frames: ./data/lvm-cdark-z1-00000646.fits
# [INFO]: combining 1 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-z1-900.fits'
#      imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 928      dark  sp2  60041     z2  00000705    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000705.fits.gz
# 966      dark  sp2  60041     z2  00000706    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000706.fits.gz
# 1016     dark  sp2  60041     z2  00000707    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60041/sdR-s-z2-00000707.fits.gz
# 1750     dark  sp2  60040     z2  00000648    900.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60040/sdR-s-z2-00000648.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-z2-00000705.fits,./data/lvm-cdark-z2-00000706.fits,./data/lvm-cdark-z2-00000707.fits,./data/lvm-cdark-z2-00000648.fits
# [INFO]: combining 4 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-z2-900.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 329     dark  sp3  60039     z3  00000518      5.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000518.fits.gz
# 448     dark  sp3  60039     z3  00000517      5.0   True  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000517.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-z3-00000518.fits,./data/lvm-cdark-z3-00000517.fits
# [INFO]: combining 2 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-z3-5.fits'
#     imagetyp spec    mjd camera    expnum  exptime  argon   neon   ldls   hgne  xenon  krypton                                                                                                                      path
# 88      dark  sp3  60039     z3  00000557    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000557.fits.gz
# 192     dark  sp3  60039     z3  00000552    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000552.fits.gz
# 196     dark  sp3  60039     z3  00000549    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000549.fits.gz
# 221     dark  sp3  60039     z3  00000555    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000555.fits.gz
# 232     dark  sp3  60039     z3  00000558    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000558.fits.gz
# 314     dark  sp3  60039     z3  00000554    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000554.fits.gz
# 343     dark  sp3  60039     z3  00000550    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000550.fits.gz
# 380     dark  sp3  60039     z3  00000551    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000551.fits.gz
# 445     dark  sp3  60039     z3  00000553    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000553.fits.gz
# 447     dark  sp3  60039     z3  00000556    600.0  False  False  False  False  False    False  /home/mejia/Research/UNAM/lvm-drp/lvmdrp/examples/data/lco_com/sas/sdsswork/data/lvm/lco/60039/sdR-s-z3-00000556.fits.gz
# [INFO]: input frames: ./data/lvm-cdark-z3-00000557.fits,./data/lvm-cdark-z3-00000552.fits,./data/lvm-cdark-z3-00000549.fits,./data/lvm-cdark-z3-00000555.fits,./data/lvm-cdark-z3-00000558.fits,./data/lvm-cdark-z3-00000554.fits,./data/lvm-cdark-z3-00000550.fits,./data/lvm-cdark-z3-00000551.fits,./data/lvm-cdark-z3-00000553.fits,./data/lvm-cdark-z3-00000556.fits
# [INFO]: combining 10 frames into master frame
# [INFO]: updating header for new master frame './data/lvm-super-mdark-z3-600.fits'

# %%
masters_dark = get_masters_metadata(path_pattern=out_calib_path, mjd="super", kind="mdark").groupby("camera")

for camera in masters_dark.groups:
    mdark = masters_dark.get_group(camera).sort_values("exptime", ascending=False).iloc[0]
    print(mdark)
    
    imageMethod.createPixelMask_drp(
        in_image=mdark.path,
        out_image=out_calib_path.format(mjd="super", kind="mask", camera=mdark.camera, exptime="x"),
        nstd=1.5
    )
# Out:
# mjd                                     super
# kind                                    mdark
# camera                                     b1
# exptime                                   900
# path       ./data/lvm-super-mdark-b1-900.fits
# Name: 8, dtype: object
# mjd                                     super
# kind                                    mdark
# camera                                     b2
# exptime                                   900
# path       ./data/lvm-super-mdark-b2-900.fits
# Name: 18, dtype: object
# mjd                                     super
# kind                                    mdark
# camera                                     b3
# exptime                                   600
# path       ./data/lvm-super-mdark-b3-600.fits
# Name: 23, dtype: object
# mjd                                     super
# kind                                    mdark
# camera                                     r1
# exptime                                   900
# path       ./data/lvm-super-mdark-r1-900.fits
# Name: 3, dtype: object
# mjd                                     super
# kind                                    mdark
# camera                                     r2
# exptime                                   900
# path       ./data/lvm-super-mdark-r2-900.fits
# Name: 14, dtype: object
# mjd                                     super
# kind                                    mdark
# camera                                     r3
# exptime                                   600
# path       ./data/lvm-super-mdark-r3-600.fits
# Name: 22, dtype: object
# mjd                                     super
# kind                                    mdark
# camera                                     z1
# exptime                                   900
# path       ./data/lvm-super-mdark-z1-900.fits
# Name: 6, dtype: object
# mjd                                     super
# kind                                    mdark
# camera                                     z2
# exptime                                   900
# path       ./data/lvm-super-mdark-z2-900.fits
# Name: 5, dtype: object
# mjd                                     super
# kind                                    mdark
# camera                                     z3
# exptime                                   600
# path       ./data/lvm-super-mdark-z3-600.fits
# Name: 20, dtype: object

# %%
master_biases = get_masters_metadata(path_pattern=out_calib_path, mjd="super", kind="mbias", camera="b2")
mbias = master_biases.iloc[0]

mbias_frame = image.loadImage(mbias.path)

fig, axs = plt.subplots(2, 2, figsize=(10,10), sharex=False, sharey=False)
axs = axs.flatten()
for i, ax in enumerate(axs):
    quad = mbias_frame.getSection(mbias_frame._header[f"AMP{i+1} TRIMSEC"])
    data = quad._data.flatten()
    ave, std = data.mean(), data.std()
    nsg = 5
    
    ax.hist(data, range=(ave-nsg*std, ave+nsg*std), bins=10, color="tab:blue")
    ax.text(0.05, 0.95, f"{'abcd'[i]}", transform=ax.transAxes)
    ax.set_yscale("log")
    
    if i in [2,3]:
        ax.set_xlabel("counts (electron/pix)")
